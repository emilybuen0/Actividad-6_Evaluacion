# %% [markdown]
# Función_1. Carga los archivos con extensiones .csv y .xlsx y los convierte a dataframe, si es un  archivo con cualquier otra extensión, emitirá el raise (“Este formato no esta soportado para esta función: .formato”)
#
# Función_2. Sustituye los valores nulos de las variables pares numéricas con el método “mean” y de las impares numéricas con la constante “99”. Las columnas que no sean de tipo numérico se sustituirán con el string “Este_es_un_valor_nulo”
#
# Función_3. Identifica los valores nulos “por columna” y “por dataframe”
#
# Función_4. Sustituye  los valores atípicos de las columnas numéricas con el método de “Rango intercuartílico”
#
# Crear el archivo de la libreria con extension (“.py”), y generar un archivo de llamado de las 4 funciones en Google COLAB o en Visual Studio Code, respaldar ambos scripts (“funciones.py” y “llamado_de_funciones.ipynb”) en GitHub, y agregar el archivo .csv del dataframe final procesado.
# Subir el link del repositorio en CANVAS para “Evaluación”

# %%
import Emily as ems

# %%
#Función 1
df = ems.cargar_dataset('HongKong_China_Data.csv')
df
# Out:
#                source    host_id   host_name  host_since host_location  \
# 0         city scrape     304876     Brendan  30/11/2010     Hong Kong
# 1     previous scrape    1300549      Darren  17/10/2011     Hong Kong
# 2         city scrape    1370155     Chuster  04/11/2011     Hong Kong
# 3         city scrape    1435069    Shanshan  23/11/2011     Hong Kong
# 4         city scrape    1443229        Shan  26/11/2011     Hong Kong
# ...               ...        ...         ...         ...           ...
# 6713      city scrape    4209137      Cherry  21/11/2012     Hong Kong
# 6714      city scrape   57341318       Edwin  04/02/2016     Hong Kong
# 6715      city scrape  667730514  James John  19/12/2024           NaN
# 6716      city scrape  280827591       Iryna  31/07/2019           NaN
# 6717      city scrape  668016531          佩涛  20/12/2024           NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0           within a day               100%                  69%
# 1         within an hour               100%                  81%
# 2     within a few hours               100%                  NaN
# 3           within a day               100%                  86%
# 4     within a few hours               100%                  88%
# ...                  ...                ...                  ...
# 6713      within an hour               100%                  98%
# 6714                 NaN                NaN                  NaN
# 6715                 NaN                NaN                  NaN
# 6716                 NaN                NaN                  NaN
# 6717                 NaN                NaN                  NaN
#
#      host_is_superhost host_neighbourhood  ...  first_review last_review  \
# 0                    f            Central  ...    19/06/2011  13/02/2024
# 1                    f         Sheung Wan  ...    30/10/2011  06/12/2024
# 2                    f           The Peak  ...           NaN         NaN
# 3                    t           Wan Chai  ...    16/12/2011  02/11/2024
# 4                    f            Stanley  ...    21/04/2012  06/12/2024
# ...                ...                ...  ...           ...         ...
# 6713                 f           Wan Chai  ...           NaN         NaN
# 6714                 f         Mid-Levels  ...           NaN         NaN
# 6715                 f     Wong Chuk Hang  ...           NaN         NaN
# 6716                 f            Sai Wan  ...           NaN         NaN
# 6717                 f         Yau Ma Tei  ...           NaN         NaN
#
#      review_scores_rating review_scores_accuracy instant_bookable  \
# 0                    4.47                   4.40                f
# 1                    4.90                   4.91                f
# 2                     NaN                    NaN                f
# 3                    4.77                   4.76                f
# 4                    4.25                   4.20                t
# ...                   ...                    ...              ...
# 6713                  NaN                    NaN                f
# 6714                  NaN                    NaN                f
# 6715                  NaN                    NaN                t
# 6716                  NaN                    NaN                f
# 6717                  NaN                    NaN                f
#
#      calculated_host_listings_count  \
# 0                                 6
# 1                                 1
# 2                                 1
# 3                                 1
# 4                                 2
# ...                             ...
# 6713                             34
# 6714                              1
# 6715                              1
# 6716                              1
# 6717                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              2
# 1                                              1
# 2                                              0
# 3                                              1
# 4                                              2
# ...                                          ...
# 6713                                          14
# 6714                                           1
# 6715                                           1
# 6716                                           0
# 6717                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               4
# 1                                               0
# 2                                               1
# 3                                               0
# 4                                               0
# ...                                           ...
# 6713                                           19
# 6714                                            0
# 6715                                            0
# 6716                                            1
# 6717                                            1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               1.92
# 1                                               0               1.37
# 2                                               0                NaN
# 3                                               0               1.90
# 4                                               0               0.36
# ...                                           ...                ...
# 6713                                            1                NaN
# 6714                                            0                NaN
# 6715                                            0                NaN
# 6716                                            0                NaN
# 6717                                            0                NaN
#
# [6718 rows x 50 columns]

# %%
#Funcion 2
CHINA = ems.sustituir_valores_nulos(df)
CHINA
# Out:
# c:\Users\B_3mi\Downloads\Analítica de Datos\Prof. Alfredo\Actividad_6.1\Emily.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[columna].fillna("Este_es_un_valor_nulo", inplace=True)
# c:\Users\B_3mi\Downloads\Analítica de Datos\Prof. Alfredo\Actividad_6.1\Emily.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[columna].fillna(99, inplace=True)
# c:\Users\B_3mi\Downloads\Analítica de Datos\Prof. Alfredo\Actividad_6.1\Emily.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[columna].fillna(df[columna].mean(), inplace=True)
#                source    host_id   host_name  host_since  \
# 0         city scrape     304876     Brendan  30/11/2010
# 1     previous scrape    1300549      Darren  17/10/2011
# 2         city scrape    1370155     Chuster  04/11/2011
# 3         city scrape    1435069    Shanshan  23/11/2011
# 4         city scrape    1443229        Shan  26/11/2011
# ...               ...        ...         ...         ...
# 6713      city scrape    4209137      Cherry  21/11/2012
# 6714      city scrape   57341318       Edwin  04/02/2016
# 6715      city scrape  667730514  James John  19/12/2024
# 6716      city scrape  280827591       Iryna  31/07/2019
# 6717      city scrape  668016531          佩涛  20/12/2024
#
#               host_location     host_response_time     host_response_rate  \
# 0                 Hong Kong           within a day                   100%
# 1                 Hong Kong         within an hour                   100%
# 2                 Hong Kong     within a few hours                   100%
# 3                 Hong Kong           within a day                   100%
# 4                 Hong Kong     within a few hours                   100%
# ...                     ...                    ...                    ...
# 6713              Hong Kong         within an hour                   100%
# 6714              Hong Kong  Este_es_un_valor_nulo  Este_es_un_valor_nulo
# 6715  Este_es_un_valor_nulo  Este_es_un_valor_nulo  Este_es_un_valor_nulo
# 6716  Este_es_un_valor_nulo  Este_es_un_valor_nulo  Este_es_un_valor_nulo
# 6717  Este_es_un_valor_nulo  Este_es_un_valor_nulo  Este_es_un_valor_nulo
#
#        host_acceptance_rate host_is_superhost host_neighbourhood  ...  \
# 0                       69%                 f            Central  ...
# 1                       81%                 f         Sheung Wan  ...
# 2     Este_es_un_valor_nulo                 f           The Peak  ...
# 3                       86%                 t           Wan Chai  ...
# 4                       88%                 f            Stanley  ...
# ...                     ...               ...                ...  ...
# 6713                    98%                 f           Wan Chai  ...
# 6714  Este_es_un_valor_nulo                 f         Mid-Levels  ...
# 6715  Este_es_un_valor_nulo                 f     Wong Chuk Hang  ...
# 6716  Este_es_un_valor_nulo                 f            Sai Wan  ...
# 6717  Este_es_un_valor_nulo                 f         Yau Ma Tei  ...
#
#                first_review            last_review review_scores_rating  \
# 0                19/06/2011             13/02/2024             4.470000
# 1                30/10/2011             06/12/2024             4.900000
# 2     Este_es_un_valor_nulo  Este_es_un_valor_nulo             4.549218
# 3                16/12/2011             02/11/2024             4.770000
# 4                21/04/2012             06/12/2024             4.250000
# ...                     ...                    ...                  ...
# 6713  Este_es_un_valor_nulo  Este_es_un_valor_nulo             4.549218
# 6714  Este_es_un_valor_nulo  Este_es_un_valor_nulo             4.549218
# 6715  Este_es_un_valor_nulo  Este_es_un_valor_nulo             4.549218
# 6716  Este_es_un_valor_nulo  Este_es_un_valor_nulo             4.549218
# 6717  Este_es_un_valor_nulo  Este_es_un_valor_nulo             4.549218
#
#      review_scores_accuracy instant_bookable calculated_host_listings_count  \
# 0                      4.40                f                              6
# 1                      4.91                f                              1
# 2                     99.00                f                              1
# 3                      4.76                f                              1
# 4                      4.20                t                              2
# ...                     ...              ...                            ...
# 6713                  99.00                f                             34
# 6714                  99.00                f                              1
# 6715                  99.00                t                              1
# 6716                  99.00                f                              1
# 6717                  99.00                f                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              2
# 1                                              1
# 2                                              0
# 3                                              1
# 4                                              2
# ...                                          ...
# 6713                                          14
# 6714                                           1
# 6715                                           1
# 6716                                           0
# 6717                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               4
# 1                                               0
# 2                                               1
# 3                                               0
# 4                                               0
# ...                                           ...
# 6713                                           19
# 6714                                            0
# 6715                                            0
# 6716                                            1
# 6717                                            1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               1.92
# 1                                               0               1.37
# 2                                               0              99.00
# 3                                               0               1.90
# 4                                               0               0.36
# ...                                           ...                ...
# 6713                                            1              99.00
# 6714                                            0              99.00
# 6715                                            0              99.00
# 6716                                            0              99.00
# 6717                                            0              99.00
#
# [6718 rows x 50 columns]

# %%
#Funcion 3
CHINA = ems.cuenta_valores_nulos(df)
CHINA
# Out:
# ('Valores nulos por columna',
#  source                                          0
#  host_id                                         0
#  host_name                                       0
#  host_since                                      0
#  host_location                                   0
#  host_response_time                              0
#  host_response_rate                              0
#  host_acceptance_rate                            0
#  host_is_superhost                               0
#  host_neighbourhood                              0
#  host_total_listings_count                       0
#  host_verifications                              0
#  host_has_profile_pic                            0
#  host_identity_verified                          0
#  neighbourhood                                   0
#  neighbourhood_cleansed                          0
#  property_type                                   0
#  room_type                                       0
#  accommodates                                    0
#  bathrooms                                       0
#  bathrooms_text                                  0
#  bedrooms                                        0
#  beds                                            0
#  amenities                                       0
#  price                                           0
#  minimum_nights                                  0
#  maximum_nights                                  0
#  minimum_minimum_nights                          0
#  maximum_minimum_nights                          0
#  minimum_maximum_nights                          0
#  maximum_maximum_nights                          0
#  minimum_nights_avg_ntm                          0
#  maximum_nights_avg_ntm                          0
#  availability_30                                 0
#  availability_60                                 0
#  availability_90                                 0
#  availability_365                                0
#  number_of_reviews                               0
#  number_of_reviews_ltm                           0
#  number_of_reviews_l30d                          0
#  first_review                                    0
#  last_review                                     0
#  review_scores_rating                            0
#  review_scores_accuracy                          0
#  instant_bookable                                0
#  calculated_host_listings_count                  0
#  calculated_host_listings_count_entire_homes     0
#  calculated_host_listings_count_private_rooms    0
#  calculated_host_listings_count_shared_rooms     0
#  reviews_per_month                               0
#  dtype: int64,
#  'Valores nulos por dataframe',
#  0)

# %%
df.to_csv("China_Procesado.csv")
